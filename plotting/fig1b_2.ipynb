# %%
library(Seurat)
library(dplyr)
library(ggplot2)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
total <- readRDS("/home/datastore2/karlso/datastore/scRNAseq_GSE155121_human_embryo_CS10to14/20230812_withvelo/Processed_data/scRNA/Step1f_cleaned_annotated.rds")

# %%
options(repr.plot.width=10, repr.plot.height=10)
DimPlot(total, group.by = 'celltype', reduction = "draw_graph_fa", label = TRUE) & NoAxes() & NoLegend()

Idents(total) <- "celltype"
levels(total) <- c("01_Epiblast",
                  '02_Non_neuroectoderm',
                  '03_Epidermal',
                  '04_Placode',
                  '05_Neural_crest',
                  '06_Neuroectoderm',
                  '07_Telencephalon',
                  '08_Diencephalon',
                  '09_Mesencephalon',
                  '10_Rhombomere',
                  '11_Roof_plate')
# Out:
# Warning message:
# “`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the Seurat package.
#   Please report the issue at <https://github.com/satijalab/seurat/issues>.”
# plot without title

# %%
Idents(total) <- "celltype"
total_subset <- subset(total, idents = c('05_Neural_crest', '04_Placode', '03_Epidermal', '02_Non_neuroectoderm'))

# %%
options(repr.plot.width=10, repr.plot.height=3, repr.plot.res = 300)
DotPlot(total_subset, features = c("DDR2",
                                   "EBF2",
                                   "PDGFRA",
                                   "EBF3",
                                   "TWIST1",
                                   "MIR205HG",
                                   "CXCL14",
                                   "S100A11",
                                   "ANXA3",
                                   "HAPLN1",
                                   "EPCAM",
                                   "CLDN4",
                                   "EYA1",
                                   "PRDM1",
                                   "WFDC2",
                                   "FOXD3-AS1",
                                   "TFAP2B",
                                   "PLP1",
                                   "MPZ",
                                   "SOX10"), cols = c("lightgrey", "purple"))
# Out:
# Warning message:
# “Scaling data with a low number of groups may produce misleading results”
# plot without title

# %%
Idents(total_subset) <- factor(total_subset@active.ident, sort(levels(total_subset@active.ident)))

# %%
options(repr.plot.width=10, repr.plot.height=3, repr.plot.res = 300)
DotPlot(total_subset, features = c("DDR2",
                                   "EBF2",
                                   "PDGFRA",
                                   "EBF3",
                                   "TWIST1",
                                   "MIR205HG",
                                   "CXCL14",
                                   "S100A11",
                                   "ANXA3",
                                   "HAPLN1",
                                   "EPCAM",
                                   "CLDN4",
                                   "EYA1",
                                   "PRDM1",
                                   "WFDC2",
                                   "FOXD3-AS1",
                                   "TFAP2B",
                                   "PLP1",
                                   "MPZ",
                                   "SOX10"), cols = c("lightgrey", "purple")) + theme(axis.text.x = element_text(angle = 45, hjust=1))
# Out:
# Warning message:
# “Scaling data with a low number of groups may produce misleading results”
# plot without title
