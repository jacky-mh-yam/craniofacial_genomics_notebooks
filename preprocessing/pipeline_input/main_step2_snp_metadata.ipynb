# %% [markdown]
# # Prepare pipeline input - SNP metadata

# %% [markdown]
# ## Loading required packages

# %%
suppressMessages(library(tidyverse))
suppressMessages(library(data.table))

# %% [markdown]
# ## Load data

# %%
# GWAS
gwas_summary <- fread("../snp_array/outputs/GWAS_Summary.bed", drop = 3, col.names = c("CHR", "BP", "SNP", "P"))

# %%
# ChIP-Seq
H3K27ac_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS13_12690_peaks")) %>% 
    mutate(H3K27ac_CS13_12690_peaks = replace(H3K27ac_CS13_12690_peaks, H3K27ac_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS13_12690_peaks, as.double))


H3K27me3_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS13_12690_peaks")) %>% 
    mutate(H3K27me3_CS13_12690_peaks = replace(H3K27me3_CS13_12690_peaks, H3K27me3_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS13_12690_peaks, as.double))


H3K4me1_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS13_12690_peaks")) %>% 
    mutate(H3K4me1_CS13_12690_peaks = replace(H3K4me1_CS13_12690_peaks, H3K4me1_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS13_12690_peaks, as.double))


H3K4me2_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS13_12690_peaks")) %>% 
    mutate(H3K4me2_CS13_12690_peaks = replace(H3K4me2_CS13_12690_peaks, H3K4me2_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS13_12690_peaks, as.double))


H3K4me3_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS13_12690_peaks")) %>% 
    mutate(H3K4me3_CS13_12690_peaks = replace(H3K4me3_CS13_12690_peaks, H3K4me3_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS13_12690_peaks, as.double))


H3K27ac_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS13_12830_peaks")) %>% 
    mutate(H3K27ac_CS13_12830_peaks = replace(H3K27ac_CS13_12830_peaks, H3K27ac_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS13_12830_peaks, as.double))


H3K27me3_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS13_12830_peaks")) %>% 
    mutate(H3K27me3_CS13_12830_peaks = replace(H3K27me3_CS13_12830_peaks, H3K27me3_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS13_12830_peaks, as.double))


H3K4me1_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS13_12830_peaks")) %>% 
    mutate(H3K4me1_CS13_12830_peaks = replace(H3K4me1_CS13_12830_peaks, H3K4me1_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS13_12830_peaks, as.double))


H3K4me2_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS13_12830_peaks")) %>% 
    mutate(H3K4me2_CS13_12830_peaks = replace(H3K4me2_CS13_12830_peaks, H3K4me2_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS13_12830_peaks, as.double))


H3K4me3_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS13_12830_peaks")) %>% 
    mutate(H3K4me3_CS13_12830_peaks = replace(H3K4me3_CS13_12830_peaks, H3K4me3_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS13_12830_peaks, as.double))


H3K27ac_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS13_12877_peaks")) %>% 
    mutate(H3K27ac_CS13_12877_peaks = replace(H3K27ac_CS13_12877_peaks, H3K27ac_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS13_12877_peaks, as.double))


H3K27me3_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS13_12877_peaks")) %>% 
    mutate(H3K27me3_CS13_12877_peaks = replace(H3K27me3_CS13_12877_peaks, H3K27me3_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS13_12877_peaks, as.double))


H3K4me1_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS13_12877_peaks")) %>% 
    mutate(H3K4me1_CS13_12877_peaks = replace(H3K4me1_CS13_12877_peaks, H3K4me1_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS13_12877_peaks, as.double))


H3K4me2_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS13_12877_peaks")) %>% 
    mutate(H3K4me2_CS13_12877_peaks = replace(H3K4me2_CS13_12877_peaks, H3K4me2_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS13_12877_peaks, as.double))


H3K4me3_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS13_12877_peaks")) %>% 
    mutate(H3K4me3_CS13_12877_peaks = replace(H3K4me3_CS13_12877_peaks, H3K4me3_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS13_12877_peaks, as.double))


H3K27ac_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS14_12408_peaks")) %>% 
    mutate(H3K27ac_CS14_12408_peaks = replace(H3K27ac_CS14_12408_peaks, H3K27ac_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS14_12408_peaks, as.double))


H3K27me3_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS14_12408_peaks")) %>% 
    mutate(H3K27me3_CS14_12408_peaks = replace(H3K27me3_CS14_12408_peaks, H3K27me3_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS14_12408_peaks, as.double))


H3K4me1_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS14_12408_peaks")) %>% 
    mutate(H3K4me1_CS14_12408_peaks = replace(H3K4me1_CS14_12408_peaks, H3K4me1_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS14_12408_peaks, as.double))


H3K4me2_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS14_12408_peaks")) %>% 
    mutate(H3K4me2_CS14_12408_peaks = replace(H3K4me2_CS14_12408_peaks, H3K4me2_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS14_12408_peaks, as.double))


H3K4me3_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS14_12408_peaks")) %>% 
    mutate(H3K4me3_CS14_12408_peaks = replace(H3K4me3_CS14_12408_peaks, H3K4me3_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS14_12408_peaks, as.double))


H3K27ac_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS14_12709_peaks")) %>% 
    mutate(H3K27ac_CS14_12709_peaks = replace(H3K27ac_CS14_12709_peaks, H3K27ac_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS14_12709_peaks, as.double))


H3K27me3_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS14_12709_peaks")) %>% 
    mutate(H3K27me3_CS14_12709_peaks = replace(H3K27me3_CS14_12709_peaks, H3K27me3_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS14_12709_peaks, as.double))


H3K4me1_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS14_12709_peaks")) %>% 
    mutate(H3K4me1_CS14_12709_peaks = replace(H3K4me1_CS14_12709_peaks, H3K4me1_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS14_12709_peaks, as.double))


H3K4me2_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS14_12709_peaks")) %>% 
    mutate(H3K4me2_CS14_12709_peaks = replace(H3K4me2_CS14_12709_peaks, H3K4me2_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS14_12709_peaks, as.double))


H3K4me3_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS14_12709_peaks")) %>% 
    mutate(H3K4me3_CS14_12709_peaks = replace(H3K4me3_CS14_12709_peaks, H3K4me3_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS14_12709_peaks, as.double))


H3K27ac_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS14_12913_peaks")) %>% 
    mutate(H3K27ac_CS14_12913_peaks = replace(H3K27ac_CS14_12913_peaks, H3K27ac_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS14_12913_peaks, as.double))


H3K27me3_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS14_12913_peaks")) %>% 
    mutate(H3K27me3_CS14_12913_peaks = replace(H3K27me3_CS14_12913_peaks, H3K27me3_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS14_12913_peaks, as.double))


H3K4me1_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS14_12913_peaks")) %>% 
    mutate(H3K4me1_CS14_12913_peaks = replace(H3K4me1_CS14_12913_peaks, H3K4me1_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS14_12913_peaks, as.double))


H3K4me2_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS14_12913_peaks")) %>% 
    mutate(H3K4me2_CS14_12913_peaks = replace(H3K4me2_CS14_12913_peaks, H3K4me2_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS14_12913_peaks, as.double))


H3K4me3_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS14_12913_peaks")) %>% 
    mutate(H3K4me3_CS14_12913_peaks = replace(H3K4me3_CS14_12913_peaks, H3K4me3_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS14_12913_peaks, as.double))


H3K27ac_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS15_13000_peaks")) %>% 
    mutate(H3K27ac_CS15_13000_peaks = replace(H3K27ac_CS15_13000_peaks, H3K27ac_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS15_13000_peaks, as.double))


H3K27me3_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS15_13000_peaks")) %>% 
    mutate(H3K27me3_CS15_13000_peaks = replace(H3K27me3_CS15_13000_peaks, H3K27me3_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS15_13000_peaks, as.double))


H3K4me1_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS15_13000_peaks")) %>% 
    mutate(H3K4me1_CS15_13000_peaks = replace(H3K4me1_CS15_13000_peaks, H3K4me1_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS15_13000_peaks, as.double))


H3K4me2_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS15_13000_peaks")) %>% 
    mutate(H3K4me2_CS15_13000_peaks = replace(H3K4me2_CS15_13000_peaks, H3K4me2_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS15_13000_peaks, as.double))


H3K4me3_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS15_13000_peaks")) %>% 
    mutate(H3K4me3_CS15_13000_peaks = replace(H3K4me3_CS15_13000_peaks, H3K4me3_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS15_13000_peaks, as.double))


H3K27ac_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS15_13019_peaks")) %>% 
    mutate(H3K27ac_CS15_13019_peaks = replace(H3K27ac_CS15_13019_peaks, H3K27ac_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS15_13019_peaks, as.double))


H3K27me3_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS15_13019_peaks")) %>% 
    mutate(H3K27me3_CS15_13019_peaks = replace(H3K27me3_CS15_13019_peaks, H3K27me3_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS15_13019_peaks, as.double))


H3K4me1_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS15_13019_peaks")) %>% 
    mutate(H3K4me1_CS15_13019_peaks = replace(H3K4me1_CS15_13019_peaks, H3K4me1_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS15_13019_peaks, as.double))


H3K4me2_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS15_13019_peaks")) %>% 
    mutate(H3K4me2_CS15_13019_peaks = replace(H3K4me2_CS15_13019_peaks, H3K4me2_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS15_13019_peaks, as.double))


H3K4me3_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS15_13019_peaks")) %>% 
    mutate(H3K4me3_CS15_13019_peaks = replace(H3K4me3_CS15_13019_peaks, H3K4me3_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS15_13019_peaks, as.double))


H3K27ac_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K27ac_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27ac_CS15_13128_peaks")) %>% 
    mutate(H3K27ac_CS15_13128_peaks = replace(H3K27ac_CS15_13128_peaks, H3K27ac_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K27ac_CS15_13128_peaks, as.double))


H3K27me3_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K27me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K27me3_CS15_13128_peaks")) %>% 
    mutate(H3K27me3_CS15_13128_peaks = replace(H3K27me3_CS15_13128_peaks, H3K27me3_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K27me3_CS15_13128_peaks, as.double))


H3K4me1_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K4me1_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me1_CS15_13128_peaks")) %>% 
    mutate(H3K4me1_CS15_13128_peaks = replace(H3K4me1_CS15_13128_peaks, H3K4me1_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K4me1_CS15_13128_peaks, as.double))


H3K4me2_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K4me2_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me2_CS15_13128_peaks")) %>% 
    mutate(H3K4me2_CS15_13128_peaks = replace(H3K4me2_CS15_13128_peaks, H3K4me2_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K4me2_CS15_13128_peaks, as.double))


H3K4me3_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K4me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K4me3_CS15_13128_peaks")) %>% 
    mutate(H3K4me3_CS15_13128_peaks = replace(H3K4me3_CS15_13128_peaks, H3K4me3_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K4me3_CS15_13128_peaks, as.double))

H3K36me3_CS13_12690_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12690-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS13_12690_peaks")) %>% 
    mutate(H3K36me3_CS13_12690_peaks = replace(H3K36me3_CS13_12690_peaks, H3K36me3_CS13_12690_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS13_12690_peaks, as.double))

H3K36me3_CS13_12830_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12830-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS13_12830_peaks")) %>% 
    mutate(H3K36me3_CS13_12830_peaks = replace(H3K36me3_CS13_12830_peaks, H3K36me3_CS13_12830_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS13_12830_peaks, as.double))

H3K36me3_CS13_12877_peaks <- fread("../chip_seq/outputs/gwas_summary_CS13-12877-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS13_12877_peaks")) %>% 
    mutate(H3K36me3_CS13_12877_peaks = replace(H3K36me3_CS13_12877_peaks, H3K36me3_CS13_12877_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS13_12877_peaks, as.double))

H3K36me3_CS14_12408_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12408-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS14_12408_peaks")) %>% 
    mutate(H3K36me3_CS14_12408_peaks = replace(H3K36me3_CS14_12408_peaks, H3K36me3_CS14_12408_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS14_12408_peaks, as.double))

H3K36me3_CS14_12709_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12709-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS14_12709_peaks")) %>% 
    mutate(H3K36me3_CS14_12709_peaks = replace(H3K36me3_CS14_12709_peaks, H3K36me3_CS14_12709_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS14_12709_peaks, as.double))

H3K36me3_CS15_13000_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13000-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS15_13000_peaks")) %>% 
    mutate(H3K36me3_CS15_13000_peaks = replace(H3K36me3_CS15_13000_peaks, H3K36me3_CS15_13000_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS15_13000_peaks, as.double))

H3K36me3_CS14_12913_peaks <- fread("../chip_seq/outputs/gwas_summary_CS14-12913-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS14_12913_peaks")) %>% 
    mutate(H3K36me3_CS14_12913_peaks = replace(H3K36me3_CS14_12913_peaks, H3K36me3_CS14_12913_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS14_12913_peaks, as.double))

H3K36me3_CS15_13019_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13019-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS15_13019_peaks")) %>% 
    mutate(H3K36me3_CS15_13019_peaks = replace(H3K36me3_CS15_13019_peaks, H3K36me3_CS15_13019_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS15_13019_peaks, as.double))

H3K36me3_CS15_13128_peaks <- fread("../chip_seq/outputs/gwas_summary_CS15-13128-H3K36me3_intersect.bed", select = c(4, 10), col.names = c("SNP", "H3K36me3_CS15_13128_peaks")) %>% 
    mutate(H3K36me3_CS15_13128_peaks = replace(H3K36me3_CS15_13128_peaks, H3K36me3_CS15_13128_peaks == ".", "0")) %>%
    mutate(across(H3K36me3_CS15_13128_peaks, as.double))

# %%
#load scRNA
epiblast <- fread("../scrna_seq/outputs/gwas_summary_epiblast_intersect.bed", select = c(4, 10), col.names = c("SNP", "epiblast")) %>% 
    mutate(epiblast = replace(epiblast, epiblast == "-1", "0")) %>%
    mutate(across(epiblast, as.double))

non_neuroectoderm <- fread("../scrna_seq/outputs/gwas_summary_non_neuroectoderm_intersect.bed", select = c(4, 10), col.names = c("SNP", "non_neuroectoderm")) %>% 
    mutate(non_neuroectoderm = replace(non_neuroectoderm, non_neuroectoderm == "-1", "0")) %>%
    mutate(across(non_neuroectoderm, as.double))

epidermal <- fread("../scrna_seq/outputs/gwas_summary_epidermal_intersect.bed", select = c(4, 10), col.names = c("SNP", "epidermal")) %>% 
    mutate(epidermal = replace(epidermal, epidermal == "-1", "0")) %>%
    mutate(across(epidermal, as.double))

placode <- fread("../scrna_seq/outputs/gwas_summary_placode_intersect.bed", select = c(4, 10), col.names = c("SNP", "placode")) %>% 
    mutate(placode = replace(placode, placode == "-1", "0")) %>%
    mutate(across(placode, as.double))

neural_crest <- fread("../scrna_seq/outputs/gwas_summary_neural_crest_intersect.bed", select = c(4, 10), col.names = c("SNP", "neural_crest")) %>% 
    mutate(neural_crest = replace(neural_crest, neural_crest == "-1", "0")) %>%
    mutate(across(neural_crest, as.double))

neuroectoderm <- fread("../scrna_seq/outputs/gwas_summary_neuroectoderm_intersect.bed", select = c(4, 10), col.names = c("SNP", "neuroectoderm")) %>% 
    mutate(neuroectoderm = replace(neuroectoderm, neuroectoderm == "-1", "0")) %>%
    mutate(across(neuroectoderm, as.double))

telencephalon <- fread("../scrna_seq/outputs/gwas_summary_telencephalon_intersect.bed", select = c(4, 10), col.names = c("SNP", "telencephalon")) %>% 
    mutate(telencephalon = replace(telencephalon, telencephalon == "-1", "0")) %>%
    mutate(across(telencephalon, as.double))

diencephalon <- fread("../scrna_seq/outputs/gwas_summary_diencephalon_intersect.bed", select = c(4, 10), col.names = c("SNP", "diencephalon")) %>% 
    mutate(diencephalon = replace(diencephalon, diencephalon == "-1", "0")) %>%
    mutate(across(diencephalon, as.double))

mesencephalon <- fread("../scrna_seq/outputs/gwas_summary_mesencephalon_intersect.bed", select = c(4, 10), col.names = c("SNP", "mesencephalon")) %>% 
    mutate(mesencephalon = replace(mesencephalon, mesencephalon == "-1", "0")) %>%
    mutate(across(mesencephalon, as.double))

rhombomere <- fread("../scrna_seq/outputs/gwas_summary_rhombomere_intersect.bed", select = c(4, 10), col.names = c("SNP", "rhombomere")) %>% 
    mutate(rhombomere = replace(rhombomere, rhombomere == "-1", "0")) %>%
    mutate(across(rhombomere, as.double))

roof_plate <- fread("../scrna_seq/outputs/gwas_summary_roof_plate_intersect.bed", select = c(4, 10), col.names = c("SNP", "roof_plate")) %>% 
    mutate(roof_plate = replace(roof_plate, roof_plate == "-1", "0")) %>%
    mutate(across(roof_plate, as.double))

# %%
colnames(epiblast) <- c("SNP", "epiblast")
colnames(non_neuroectoderm) <- c("SNP", "non_neuroectoderm")
colnames(epidermal) <- c("SNP", "epidermal")
colnames(placode) <- c("SNP", "placode")
colnames(neural_crest) <- c("SNP", "neural_crest")
colnames(neuroectoderm) <- c("SNP", "neuroectoderm")
colnames(telencephalon) <- c("SNP", "telencephalon")
colnames(diencephalon) <- c("SNP", "diencephalon")
colnames(mesencephalon) <- c("SNP", "mesencephalon")
colnames(rhombomere) <- c("SNP", "rhombomere")
colnames(roof_plate) <- c("SNP", "roof_plate")

# %% [markdown]
# ## Add Epigenomic Scores

# %%
gwas_epigenome_overlapped <- list(gwas_summary, 
                H3K27ac_CS13_12690_peaks, H3K27me3_CS13_12690_peaks, H3K4me1_CS13_12690_peaks, H3K4me2_CS13_12690_peaks, H3K4me3_CS13_12690_peaks, H3K36me3_CS13_12690_peaks, 
                H3K27ac_CS13_12830_peaks, H3K27me3_CS13_12830_peaks, H3K4me1_CS13_12830_peaks, H3K4me2_CS13_12830_peaks, H3K4me3_CS13_12830_peaks, H3K36me3_CS13_12830_peaks, 
                H3K27ac_CS13_12877_peaks, H3K27me3_CS13_12877_peaks, H3K4me1_CS13_12877_peaks, H3K4me2_CS13_12877_peaks, H3K4me3_CS13_12877_peaks, H3K36me3_CS13_12877_peaks, 
                H3K27ac_CS14_12408_peaks, H3K27me3_CS14_12408_peaks, H3K4me1_CS14_12408_peaks, H3K4me2_CS14_12408_peaks, H3K4me3_CS14_12408_peaks, H3K36me3_CS14_12408_peaks, 
                H3K27ac_CS14_12709_peaks, H3K27me3_CS14_12709_peaks, H3K4me1_CS14_12709_peaks, H3K4me2_CS14_12709_peaks, H3K4me3_CS14_12709_peaks, H3K36me3_CS14_12709_peaks, 
                H3K27ac_CS14_12913_peaks, H3K27me3_CS14_12913_peaks, H3K4me1_CS14_12913_peaks, H3K4me2_CS14_12913_peaks, H3K4me3_CS14_12913_peaks, H3K36me3_CS14_12913_peaks, 
                H3K27ac_CS15_13000_peaks, H3K27me3_CS15_13000_peaks, H3K4me1_CS15_13000_peaks, H3K4me2_CS15_13000_peaks, H3K4me3_CS15_13000_peaks, H3K36me3_CS15_13000_peaks, 
                H3K27ac_CS15_13019_peaks, H3K27me3_CS15_13019_peaks, H3K4me1_CS15_13019_peaks, H3K4me2_CS15_13019_peaks, H3K4me3_CS15_13019_peaks, H3K36me3_CS15_13019_peaks, 
                H3K27ac_CS15_13128_peaks, H3K27me3_CS15_13128_peaks, H3K4me1_CS15_13128_peaks, H3K4me2_CS15_13128_peaks, H3K4me3_CS15_13128_peaks, H3K36me3_CS15_13128_peaks
               ) %>% reduce(full_join, by='SNP')

# %%
# dataframe for holding values
gwas_epigenome_overlapped_rep_merged <- gwas_epigenome_overlapped[, c(1:4)]

# merge biological replicates by averaging peak scores
gwas_epigenome_overlapped_rep_merged$H3K27ac_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27ac_CS13_12690_peaks", "H3K27ac_CS13_12830_peaks", "H3K27ac_CS13_12877_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K27me3_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27me3_CS13_12690_peaks", "H3K27me3_CS13_12830_peaks", "H3K27me3_CS13_12877_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me1_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me1_CS13_12690_peaks", "H3K4me1_CS13_12830_peaks", "H3K4me1_CS13_12877_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me2_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me2_CS13_12690_peaks", "H3K4me2_CS13_12830_peaks", "H3K4me2_CS13_12877_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me3_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me3_CS13_12690_peaks", "H3K4me3_CS13_12830_peaks", "H3K4me3_CS13_12877_peaks")], na.rm = TRUE)


gwas_epigenome_overlapped_rep_merged$H3K27ac_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27ac_CS14_12408_peaks", "H3K27ac_CS14_12709_peaks", "H3K27ac_CS14_12913_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K27me3_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27me3_CS14_12408_peaks", "H3K27me3_CS14_12709_peaks", "H3K27me3_CS14_12913_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me1_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me1_CS14_12408_peaks", "H3K4me1_CS14_12709_peaks", "H3K4me1_CS14_12913_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me2_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me2_CS14_12408_peaks", "H3K4me2_CS14_12709_peaks", "H3K4me2_CS14_12913_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me3_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me3_CS14_12408_peaks", "H3K4me3_CS14_12709_peaks", "H3K4me3_CS14_12913_peaks")], na.rm = TRUE)


gwas_epigenome_overlapped_rep_merged$H3K27ac_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27ac_CS15_13000_peaks", "H3K27ac_CS15_13019_peaks", "H3K27ac_CS15_13128_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K27me3_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K27me3_CS15_13000_peaks", "H3K27me3_CS15_13019_peaks", "H3K27me3_CS15_13128_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me1_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me1_CS15_13000_peaks", "H3K4me1_CS15_13019_peaks", "H3K4me1_CS15_13128_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me2_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me2_CS15_13000_peaks", "H3K4me2_CS15_13019_peaks", "H3K4me2_CS15_13128_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K4me3_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K4me3_CS15_13000_peaks", "H3K4me3_CS15_13019_peaks", "H3K4me3_CS15_13128_peaks")], na.rm = TRUE)


gwas_epigenome_overlapped_rep_merged$H3K36me3_CS13_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K36me3_CS13_12690_peaks", "H3K36me3_CS13_12830_peaks", "H3K36me3_CS13_12877_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K36me3_CS14_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K36me3_CS14_12408_peaks", "H3K36me3_CS14_12709_peaks", "H3K36me3_CS14_12913_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_merged$H3K36me3_CS15_rep_merged_peaks <- rowMeans(gwas_epigenome_overlapped[, c("H3K36me3_CS15_13000_peaks", "H3K36me3_CS15_13019_peaks", "H3K36me3_CS15_13128_peaks")], na.rm = TRUE)

# %%
# dataframe for holding values
gwas_epigenome_overlapped_rep_stage_merged <- gwas_epigenome_overlapped[, c(1:4)]

# merge stages by averaging peak scores
gwas_epigenome_overlapped_rep_stage_merged$H3K27ac <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K27ac_CS13_rep_merged_peaks", "H3K27ac_CS14_rep_merged_peaks", "H3K27ac_CS15_rep_merged_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_stage_merged$H3K27me3 <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K27me3_CS13_rep_merged_peaks", "H3K27me3_CS14_rep_merged_peaks", "H3K27me3_CS15_rep_merged_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_stage_merged$H3K4me1 <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K4me1_CS13_rep_merged_peaks", "H3K4me1_CS14_rep_merged_peaks", "H3K4me1_CS15_rep_merged_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_stage_merged$H3K4me2 <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K4me2_CS13_rep_merged_peaks", "H3K4me2_CS14_rep_merged_peaks", "H3K4me2_CS15_rep_merged_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_stage_merged$H3K4me3 <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K4me3_CS13_rep_merged_peaks", "H3K4me3_CS14_rep_merged_peaks", "H3K4me3_CS15_rep_merged_peaks")], na.rm = TRUE)
gwas_epigenome_overlapped_rep_stage_merged$H3K36me3 <- rowMeans(gwas_epigenome_overlapped_rep_merged[, c("H3K36me3_CS13_rep_merged_peaks", "H3K36me3_CS14_rep_merged_peaks", "H3K36me3_CS15_rep_merged_peaks")], na.rm = TRUE)

# %% [markdown]
# ## Add Transcriptome Scores

# %%
snp_scoring_input <- list(gwas_epigenome_overlapped_rep_stage_merged,
                          epiblast, non_neuroectoderm, epidermal, placode, neural_crest,
                          neuroectoderm, telencephalon, diencephalon, mesencephalon, rhombomere, roof_plate
                         ) %>% reduce(full_join, by='SNP')

# %% [markdown]
# ## Clean up

# %%
snp_metadata <- snp_scoring_input %>% 
                        drop_na() %>% 
                        distinct(SNP, .keep_all = TRUE) %>%
                        select(-c('CHR', 'BP'))

# %%
# keep only relevant cell types for downstream analysis
snp_metadata <- snp_metadata %>%
                        select(-c('epiblast', 
                                  'neuroectoderm', 
                                  'telencephalon', 
                                  'diencephalon', 
                                  'mesencephalon', 
                                  'rhombomere', 
                                  'roof_plate'))

# %% [markdown]
# ## View table

# %%
options(repr.matrix.max.cols=50)
summary(snp_metadata$P)
snp_metadata
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.0000  0.2399  0.4896  0.4927  0.7432  1.0000
#        SNP         P         H3K27ac  H3K27me3 H3K4me1   H3K4me2    H3K4me3
# 1      rs4475691   8.423e-01 0         0.00000 119.66667   0.000000    0.000
# 2      rs6660139   5.980e-01 0         0.00000   0.00000   0.000000    0.000
# 3      rs3128108   3.753e-01 0         0.00000   0.00000   0.000000    0.000
# 4      rs3128117   7.298e-02 0         0.00000   0.00000   0.000000    0.000
# 5      rs115413462 8.946e-01 0         0.00000   0.00000   0.000000    0.000
# 6      rs6671356   6.475e-01 0         0.00000   0.00000   0.000000    0.000
# 7      rs113657720 1.264e-01 0         0.00000  21.22222  18.777778    0.000
# 8      rs77277598  6.190e-01 0         0.00000  58.77778   8.222222    0.000
# 9      rs4970421   5.146e-02 0        24.66667  44.11111  33.888889    0.000
# 10     rs11260542  7.313e-01 0        24.66667  17.11111   0.000000    0.000
# ...

# %% [markdown]
# ## Export SNP meta

# %%
write.table(snp_metadata, file = "outputs/snp_metadata.txt", sep = "\t", row.names = FALSE, col.names = TRUE, quote = FALSE)
